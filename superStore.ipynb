# %% [markdown]
#                            FUNCTION - Data Science & BusinessAnalytics
#
#                             TASK - Exploratory Data Analysis - Retail
#
#                                    NAME - PIYUSH GHOSH

# %%
#Importing neccessary libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("SampleSuperstore.csv")
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
## check nan value
nan_df=df[df.isna().any(axis=1)]
nan_df.head()
# Out:
# Empty DataFrame
# Columns: [Ship Mode, Segment, Country, City, State, Postal Code, Region, Category, Sub-Category, Sales, Quantity, Discount, Profit]
# Index: []

# %%
# check for duplicate
df.duplicated().sum()
# Out:
# 17

# %%
df.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
# Remove  columns  
df.drop([ 'Postal Code'], inplace=True,axis = 1)

# %%
# Correlation b/w categories
df.corr()
# Out:
#              Sales  Quantity  Discount    Profit
# Sales     1.000000  0.200795 -0.028190  0.479064
# Quantity  0.200795  1.000000  0.008623  0.066253
# Discount -0.028190  0.008623  1.000000 -0.219487
# Profit    0.479064  0.066253 -0.219487  1.000000

# %%
df.hist(bins=50,figsize=(20,15))
plt.show()

# %%
#covariance of columns
df.cov()
# Out:
#                   Sales    Quantity   Discount        Profit
# Sales     388434.455308  278.459923  -3.627228  69944.096586
# Quantity     278.459923    4.951113   0.003961     34.534769
# Discount      -3.627228    0.003961   0.042622    -10.615173
# Profit     69944.096586   34.534769 -10.615173  54877.798055

# %%
sns.heatmap(df.corr() , annot=True)

# %%
# State wise Count
plt.figure(figsize=(10,5))
sns.countplot(x=df['State'])
plt.xticks(rotation=90)
plt.title('STATE')
plt.show()

# %% [markdown]
# # Q1) Which city has the highest no: of sales & profit

# %%
# sales of each city

high_sales=df.groupby("City")['Sales'].sum().sort_values(ascending=False)
high_sales.head(10)
# Out:
# City
# New York City    256368.1610
# Los Angeles      175851.3410
# Seattle          119540.7420
# San Francisco    112669.0920
# Philadelphia     109077.0130
# Houston           64504.7604
# Chicago           48539.5410
# San Diego         47521.0290
# Jacksonville      44713.1830
# Springfield       43054.3420
# Name: Sales, dtype: float64

# %%
from matplotlib import style
style.use('dark_background')
flg,ax=plt.subplots(figsize=(16,8))
ax.scatter(df['Sales'],df['Profit'])
ax.set_xlabel('Sales')
ax.set_xlabel('Profit')
plt.show()

# %%
high_sales[:20].plot(kind='line')

# %%
# Top profitable cities

cus_city=df[['City','Profit']]
top=pd.DataFrame(cus_city.groupby(['City'])['Profit'].aggregate('sum').reset_index().sort_values('Profit',ascending=False))
top
# Out:
#               City      Profit
# 329  New York City  62036.9837
# 266    Los Angeles  30440.7579
# 452        Seattle  29156.0967
# 438  San Francisco  17507.3854
# 123        Detroit  13181.7908
# ..             ...         ...
# 80         Chicago  -6654.5688
# 241      Lancaster  -7239.0684
# 434    San Antonio  -7299.0502
# 207        Houston -10153.5485
# 374   Philadelphia -13837.7674
#
# [531 rows x 2 columns]

# %%
# profit earned by each city

cus_city=df[['City','Profit']]
pd.DataFrame(cus_city.groupby(['City'])['Profit'].aggregate('sum').reset_index())

#cus_city=df[['City','Profit']]
#pd.DataFrame(cus_city.groupby(['City'])['Profit'].sum())

# %%
sns.countplot(x="Segment",data=df , palette='rainbow')
df.groupby('Segment')['Profit','Sales'].sum().plot.bar(color=['red','blue'],figsize=(8,5))
plt.show()
# Out:
# <ipython-input-64-8a8cb454a71d>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby('Segment')['Profit','Sales'].sum().plot.bar(color=['red','blue'],figsize=(8,5))

# %%
## profit discount relation 

plt.figure(figsize=(10,4))
sns.lineplot('Discount','Profit', data=df , color='y',label='Discount')
plt.legend()
plt.show()

# %% [markdown]
# ## Q2 state with high number of purchase

# %%
high_purchases=df.groupby("State")['Quantity'].sum().sort_values(ascending=False)
high_purchases.head(10)
# Out:
# State
# California        7667
# New York          4224
# Texas             3724
# Pennsylvania      2153
# Washington        1883
# Illinois          1845
# Ohio              1759
# Florida           1379
# North Carolina     983
# Michigan           946
# Name: Quantity, dtype: int64

# %%
# Top 5 state with high number of purchase
high_purchases[:5].plot(kind = 'bar')

# %% [markdown]
# ## Q3) which product sold the most?

# %%
product_group = df.groupby('Sub-Category')
quantity_sold = product_group.sum()['Sales']
keys = [pair for pair, df in product_group]
plt.bar(keys, quantity_sold)
plt.xticks(keys, rotation='vertical', size=8)
plt.show()

# plt.figure(figsize=(12,10))
# df["Sub-Category"].value_counts().plot.pie(autopct='dark')
# plt.show()

# %% [markdown]
# ## Answer :

# %% [markdown]
# ###  Performance Analysis
# Sales Performance can be seen with

# %% [markdown]
# 1) sales wih respect to every city
#
# 2) Consumption of products of every state
#
# 3) Product oftenly purchased

# %% [markdown]
# ## Q4) Profit based on region

# %%
plt.figure(figsize=(10,6))
df["Region"].value_counts().plot.pie(autopct='%1.1f%%')
plt.show()

# %%
pd.crosstab(df["Region"], df["Category"]).plot(kind="bar", figsize=(20,10))
plt.xticks(rotation=45)
plt.plot()
# Out:
# []

# %% [markdown]
# ### Based on your analysis of the data, what are potential areas of improvement for the business?
#
# ** state , city with more number of customers
#
# ** state , city with less number of customers
#
# ** preference with region

# %% [markdown]
# ## Q5) Analysis of profit against few categories

# %%
ship1=pd.DataFrame(df.groupby(['Ship Mode'])['Profit'].sum()).reset_index()
ship1.plot(kind='bar',x="Ship Mode",y='Profit')

#OR

# ggplot(sample, aes(x='Ship Mode', fill = 'Category')) + geom_bar(stat = 'count')

# %%
category = df.groupby("Sub-Category")["Profit", "Sales"].sum()
category.plot.bar(figsize=(15,10))
# Out:
# <ipython-input-36-2ebd7696ed62>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   category = df.groupby("Sub-Category")["Profit", "Sales"].sum()

# %% [markdown]
#  1) We observe that although our sales are very high the profit we are making is very low
# 2) The best Sales vs Profit ratio we obtain is from copiers
# 3) When it comes to tables , although our sales are very high but we are still at a loss , the same applies with book cases

# %%
cp=pd.DataFrame(df.groupby(['Category'])['Profit'].sum()).reset_index()
cp.plot(kind='bar',x="Category",y='Profit')

# %%
# Combination of sub-category based on ship mode
# ggplot(sample, aes(x='Ship Mode', fill = 'Category')) + geom_bar(stat = 'count')

# %%
cp2=pd.DataFrame(df.groupby(['Sub-Category'])['Profit'].sum()).reset_index()
cp2.plot(kind='bar',x="Sub-Category",y='Profit')

# %%
plt.figure(figsize=(12,8))
plt.title('SEGMENT WISE SALES IN EACH REGION')
sns.barplot(x='Region',y='Sales',data=df,hue='Segment',order=df['Region'].value_counts().index,palette='rocket')
plt.xlabel('Region',fontsize=15)
plt.show()

# %% [markdown]
# 1) Office Supplies Lead in every sales in all the regions
# 2) The most sales occur in the west followed by east
# 3) Sales are least in the South
#
# Conclusion
# Weak Areas:
# 1) Although Copiers are the least sold products , they make the most profit and hence we must look for ways to improve the sales of Copiers
# 2)When it comes to selling tables , our sales is high but we are still facing loss , so we should stop selling tables at all till the rest of the sales isnt imporving
# 3) We should try to look for ways to imporve our sales in North, South Dakota , West Virginia and Columbia
# 4)Our sales at Ohio, Texas and Pennsylvania are running on loss
#
# Therefore in order to improve our sales and profit we must pay special attention to our losses and strengthern our weak areas¶

# %% [markdown]
# ### The above figures shows the profit and loss of each and every subcategories.
#
# Here from the graph we can visualize that "binders" sub-category has suffered the highest amount of loss and also profit amongst all other sub-Categories (For now we can't say that what is the reason it may be because of discounts given on binders subcategory).
#
#
# Next,"Copiers" sub-category has gained highest amount of profit with no loss.There are other sub-categories too haven't faced any kind of losses but their profit margins are also low.

# %%
pd.DataFrame(df['Profit'].describe())
# Out:
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %% [markdown]
# ## What are additional business problems that can be analyzed using this data. Support with explanation.

# %%
# Sales Average of each product
figsize=(15,10)
sns.pairplot(df,hue='Sub-Category')
plt.show
# avg_sales = df.groupby(['Category','Sub-Category'])['Quantity','TotalAmount'].mean().sort_values(by = 'Quantity',ascending=false)
# avg_sales
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %% [markdown]
# Answers
# We can see the demand for each product
# We can further check month wise on which product is on more demand for which month. If there is any seasonality for the product
# Further deeper analysis can be carried out customer wise

# %% [markdown]
# From the above data visualization,we can see the states and the category where sales and profits are high or less. We can improve in those states by providing discounts in prefered range so that the company and cosumer will both be in profit. Here, while the superstore is incurring losses by providing discounts on their products, they can't stop doing so. Most of the heavy discounts are during festivals, end-of-season and clearance sales which are necessary so that the store can make space in their warehouses for fresh stock. Also, by incurring small losses, the company gains in the future by attracting more long term customers. Therefore, the small losses from discounts are an essential part of company's businesses.

# %% [raw]
# top=top[:3]
# ax = sns.barplot(x="City", y="Profit", hue="city", data=top)

# %% [raw]
# Profit_plot = (ggplot(sample, aes(x='Sub-Category', y='Profit', fill='Sub-Category')) + geom_col() + coord_flip()
# + scale_fill_brewer(type='div', palette="Spectral") + theme_classic() + ggtitle('Pie Chart'))
#
# display(Profit_plot)

# %% [raw]
# plt.figure(figsize=(16,8))
# plt.bar('Sub-Category','Category', data=df)
# plt.title('Category vs Sub Category')
# plt.xlabel('Sub-Catgory')
# plt.ylabel('Category')
# plt.xticks(rotation=45)
# plt.show()

# %% [raw]
# flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
#                      axis_ticks_length_major=10,axis_ticks_length_minor=5)
# (ggplot(sample, aes(x='Sub-Category', fill='Sales')) + geom_bar() + facet_wrap(['Segment'])
# + flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Sales From Every Segment Of United States of Whole Data"))

# %% [raw]
# flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=1),figure_size=(10,5),
#                      axis_ticks_length_major=10,axis_ticks_length_minor=5)
# (ggplot(sample, aes(x='Sub-Category', fill='Discount')) + geom_bar() + facet_wrap(['Segment'])
# + flip_xlabels +theme(axis_text_x = element_text(size=12))+ggtitle("Discount on Categories From Every Segment Of United States of Whole Data"))

# %% [raw]
# flip_xlabels = theme(axis_text_x = element_text(angle=90, hjust=10),figure_size=(10,10),
#                      axis_ticks_length_major=50,axis_ticks_length_minor=50)
# (ggplot(sample1, aes(x='Category', fill='Sales')) + geom_bar() + theme(axis_text_x = element_text(size=10))
# + facet_wrap(['Region']) + flip_xlabels+ ggtitle("Sales From Every Region Of United States of Whole Data"))

# %% [raw]
# # Import pandas package
# import pandas as pd
#
# # create a dictionary with five fields each
# data = {
#     'A':['A1', 'A2', 'A3', 'A4', 'A5'],
#     'B':['B1', 'B2', 'B3', 'B4', 'B5'],
#     'C':['C1', 'C2', 'C3', 'C4', 'C5'],
#     'D':['D1', 'D2', 'D3', 'D4', 'D5'],
#     'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
#
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)
#
# # Remove two columns name is 'C' and 'D'
# df.drop(['C', 'D'], axis = 1)
#
# # df.drop(columns =['C', 'D'])

# %% [raw]
# # Import pandas package
# import pandas as pd
#
# # create a dictionary with five fields each
# data = {
#     'A':['A1', 'A2', 'A3', 'A4', 'A5'],
#     'B':['B1', 'B2', 'B3', 'B4', 'B5'],
#     'C':['C1', 'C2', 'C3', 'C4', 'C5'],
#     'D':['D1', 'D2', 'D3', 'D4', 'D5'],
#     'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
#
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)
#
# # Remove three columns as index base
# df.drop(df.columns[[0, 4, 2]], axis = 1, inplace = True)
#
# df

# %% [raw]
# # Import pandas package
# import pandas as pd
# # create a dictionary with five fields each
# data = {
#     'A':['A1', 'A2', 'A3', 'A4', 'A5'],
#     'B':['B1', 'B2', 'B3', 'B4', 'B5'],
#     'C':['C1', 'C2', 'C3', 'C4', 'C5'],
#     'D':['D1', 'D2', 'D3', 'D4', 'D5'],
#     'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
#
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)
#
# # Remove all columns between column index 1 to 3
# df.drop(df.iloc[:, 1:3], inplace = True, axis = 1)
#
# df

# %% [raw]
# # Import pandas package
# import pandas as pd
#
# # create a dictionary with five fields each
# data = {
#     'A':['A1', 'A2', 'A3', 'A4', 'A5'],
#     'B':['B1', 'B2', 'B3', 'B4', 'B5'],
#     'C':['C1', 'C2', 'C3', 'C4', 'C5'],
#     'D':['D1', 'D2', 'D3', 'D4', 'D5'],
#     'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
#
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)
#
# # Remove all columns between column name 'B' to 'D'
# df.drop(df.loc[:, 'B':'D'].columns, axis = 1)

# %% [raw]
# # Import pandas package
# import pandas as pd
#
# # create a dictionary with five fields each
# data = {
#     'A':['A1', 'A2', 'A3', 'A4', 'A5'],
#     'B':['B1', 'B2', 'B3', 'B4', 'B5'],
#     'C':['C1', 'C2', 'C3', 'C4', 'C5'],
#     'D':['D1', 'D2', 'D3', 'D4', 'D5'],
#     'E':['E1', 'E2', 'E3', 'E4', 'E5'] }
#
# # Convert the dictionary into DataFrame
# df = pd.DataFrame(data)
# for col in df.columns:
#     if 'A' in col:
#         del df[col]
#
# df

# %% [raw]
# colors = ['red','yellow','blue']
# top=top[:3]
# explode = [0,0.1,0.1]
# c=['New York City','Los Angeles','Seattle']
# plt.figure(figsize = (5,5))
# plt.pie([len(top),labels=c,explode=explode,colors=colors,autopct='%1.1f%%')
# plt.title('Profit status',color = 'blue',fontsize = 15)
# plt.show()
